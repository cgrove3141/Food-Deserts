# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Obtained Dataset from USDA on food access measures in 2010 and 2015
# - https://www.ers.usda.gov/data-products/food-access-research-atlas/
# - Converted .xlsx file to .csv in Excel

# %%
all_data = pd.read_csv("DataDownload2015.csv")

# %%
all_data
# Out:
#        CensusTract    State    County  Urban  POP2010  OHU2010  \
# 0       1001020100  Alabama   Autauga      1     1912      693
# 1       1001020200  Alabama   Autauga      1     2170      743
# 2       1001020300  Alabama   Autauga      1     3373     1256
# 3       1001020400  Alabama   Autauga      1     4386     1722
# 4       1001020500  Alabama   Autauga      1    10766     4082
# ...            ...      ...       ...    ...      ...      ...
# 72859  56043000200  Wyoming  Washakie      0     3326     1317
# 72860  56043000301  Wyoming  Washakie      1     2665     1154
# 72861  56043000302  Wyoming  Washakie      1     2542     1021
# 72862  56045951100  Wyoming    Weston      0     3314     1322
# 72863  56045951300  Wyoming    Weston      1     3894     1699
#
#        GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 0                      0         0  0.000000                  0  ...
# ...

# %% [markdown]
# ### Split files into Urban/Rural

# %%
urban = all_data.loc[all_data["Urban"]==1]
rural = all_data.loc[all_data["Urban"]==0]

# %% [markdown]
# ### Split data into quarters by each desert range and remove non-relevant columns from each quartered DF

# %%
urban_half = urban.iloc[:,np.r_[4:8,13:16,20,31:56]]

# %%
urban_one = urban.iloc[:,np.r_[4:8,13:16,21,57:82]]

# %%
rural_ten = rural.iloc[:,np.r_[4:8,13:16,22,83:108]]

# %%
rural_twenty = rural.iloc[:,np.r_[4:8,13:16,22,109:134]]

# %%
urban_half.to_csv("urban_half.csv")
